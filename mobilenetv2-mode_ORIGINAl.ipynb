# %% [markdown]
# # Violence Detection with MobileNetV2
#
# This notebook trains a MobileNetV2 model for violence detection in videos.

# %%
import tensorflow as tf
import platform
import subprocess
import os

tf.random.set_seed(73)
TPU_INIT = False

# Uncomment the following line to disable GPU support
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Configure TensorFlow to use GPU memory efficiently
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"{len(gpus)} GPU(s) found and configured.")
    except RuntimeError as e:
        print("Error configuring GPU memory:", e)
else:
    print("No GPU found by TensorFlow.")

# Check GPU status depending on OS
system_platform = platform.system()
if system_platform in ['Linux', 'Darwin', 'Windows']:
    try:
        result = subprocess.run(["nvidia-smi"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        if result.returncode == 0:
            print("nvidia-smi output:\n", result.stdout)
        else:
            print("nvidia-smi not found or no NVIDIA GPU available.")
    except FileNotFoundError:
        print("nvidia-smi not found. Make sure NVIDIA drivers are installed.")
else:
    print(f"No NVIDIA GPU check supported for platform: {system_platform}")

print("TensorFlow version:", tf.__version__)
# Out:
# No GPU found by TensorFlow.
# nvidia-smi output:
#  Thu May 29 14:01:52 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.28                 Driver Version: 576.28         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650 Ti   WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P8              4W /   50W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#
# TensorFlow version: 2.10.0

# %%
import os
import platform
from IPython.display import clear_output
print(platform.platform())

# Helper functions for directory management
def resolve_dir(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)

def reset_path(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)
    else:
        # Remove files in the directory
        for filename in os.listdir(Dir):
            file_path = os.path.join(Dir, filename)
            try:
                if os.path.isfile(file_path):  # Remove files only
                    os.remove(file_path)
            except Exception as e:
                print(f"Error deleting file {file_path}: {e}")

# Create model directory if it doesn't exist
resolve_dir('model')
# Out:
# Windows-10-10.0.26100-SP0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17349075912513688198
# xla_global_id: -1
# ]

# %% [markdown]
# ## Dataset Configuration

# %%
# Base directory of your project
PROJECT_DIR = os.path.join(os.getcwd(), 'data')  # ./data/

# Check dataset contents
print("Dataset path:", PROJECT_DIR)
print("Classes:", os.listdir(PROJECT_DIR))  # Should show ['Violence', 'NonViolence']
# Out:
# Dataset path: c:\Users\USER\Documents\GitHub\CCDEPLRL_PROJECT\data
# Classes: ['NonViolence', 'Violence']

# %%
# Function to convert videos to frames
import cv2

IMG_SIZE = 128  # REDUCED from 224 to improve performance
ColorChannels = 3

def video_to_frames(video_path):
    """Extract frames from video"""
    frames = []
    vidcap = cv2.VideoCapture(video_path)
    success, image = vidcap.read()
    count = 0
    while success:
        if count % 5 == 0:  # Take every 5th frame to reduce redundancy
            image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
            frames.append(image)
        success, image = vidcap.read()
        count += 1
    vidcap.release()
    return frames

# %% [markdown]
# ## Load and Prepare Dataset

# %%
from tqdm import tqdm
import numpy as np

VideoDataDir = os.path.join(PROJECT_DIR)  # Path to 'data'
print('We have \n{} Violence images \n{} NonViolence images'.format(
          len(os.listdir(os.path.join(VideoDataDir, 'Violence'))), 
          len(os.listdir(os.path.join(VideoDataDir, 'NonViolence')))))

X_original = []
y_original = []

# We'll process images instead of videos since we've already extracted frames
CLASSES = ["NonViolence", "Violence"]   
MAX_SAMPLES_PER_CLASS = 10000  # REDUCED from 1000 to lower memory usage

for category in CLASSES:
    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)
    print(f"Processing {category} images...")
    
    files = os.listdir(path)
    if len(files) > MAX_SAMPLES_PER_CLASS:
        files = files[:MAX_SAMPLES_PER_CLASS]
        
    for i, img_file in enumerate(tqdm(files)):
        img_path = os.path.join(path, img_file)
        try:
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                X_original.append(img)
                y_original.append(class_num)
        except Exception as e:
            print(f"Error processing {img_path}: {e}")

# Convert to numpy arrays
X_original = np.array(X_original).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
y_original = np.array(y_original)

print(f"Total samples: {len(X_original)}")
print(f"Shape of X: {X_original.shape}")
print(f"Shape of y: {y_original.shape}")
# Out:
# We have
# 53372 Violence images
# 42912 NonViolence images
# Processing NonViolence images...
# 100%|██████████| 10000/10000 [00:43<00:00, 228.62it/s]
# Processing Violence images...
# 100%|██████████| 10000/10000 [00:54<00:00, 185.05it/s]
# Total samples: 20000
# Shape of X: (20000, 128, 128, 3)
# Shape of y: (20000,)

# %% [markdown]
# ## Split Data into Training and Testing Sets

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Reshape X for the split
X_reshaped = X_original.reshape(-1, IMG_SIZE * IMG_SIZE * 3)
print("reshape done")
stratified_sample = StratifiedShuffleSplit(
    n_splits=1, test_size=0.2, random_state=73
)  # REDUCED test size from 0.3 to 0.2
print("stratified done")
for train_index, test_index in stratified_sample.split(X_reshaped, y_original):
    X_train, X_test = X_reshaped[train_index], X_reshaped[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]
print("looping done")
# Reshape back and normalize
X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255.0
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255.0



print(f"Training set: {X_train_nn.shape}, {y_train.shape}")
print(f"Testing set: {X_test_nn.shape}, {y_test.shape}")
# Out:
# reshape done
# stratified done
# looping done
# Training set: (16000, 128, 128, 3), (16000,)
# Testing set: (4000, 128, 128, 3), (4000,)

# %% [markdown]
# ## Define and Build the MobileNetV2 Model

# %%
import cv2
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

from keras.layers import Input, GlobalAveragePooling2D, BatchNormalization, Dropout, Flatten, Dense
from keras.models import Model
from keras import regularizers
from keras.applications import MobileNetV2

epochs = 50  # INCREASED from 30 to allow model to converge better
kernel_regularizer = regularizers.l2(0.0005)  # INCREASED regularization

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV2(pooling='avg',
                            include_top=False,
                            input_tensor=input_tensor,
                            alpha=0.75)  # ADDED alpha parameter to reduce model size
    
    headModel = baseModel.output
    # Add regularization and dropout to prevent overfitting
    headModel = Dropout(0.4)(headModel)  # ADDED dropout
    headModel = Dense(1, activation="sigmoid", 
                     kernel_regularizer=kernel_regularizer)(headModel)
    
    model = Model(inputs=baseModel.input, outputs=headModel)

    # Freeze base model layers
    for layer in baseModel.layers:
        layer.trainable = False

    print("Compiling model...")
    model.compile(loss="binary_crossentropy",
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # ADJUSTED learning rate
                  metrics=["accuracy"])

    return model

model = load_layers()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Compiling model...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 64, 64, 24)   648         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 64, 64, 24)   96          ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 64, 64, 24)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 64, 64, 24)  216         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 64, 64, 24)  96          ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 64, 64, 24)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 64, 64, 16)  384         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 64, 64, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 64, 64, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 64, 64, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 64, 64, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 65, 65, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 32, 32, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 32, 32, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 32, 32, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 32, 32, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 32, 32, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 32, 32, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 32, 32, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 32, 32, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 32, 32, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 32, 32, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 32, 32, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 32, 32, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 32, 32, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 32, 32, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 32, 32, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 32, 32, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 32, 32, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 33, 33, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 16, 16, 24)   3456        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 16, 16, 24)   3456        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 16, 16, 24)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 16, 16, 24)   3456        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 16, 16, 24)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 17, 17, 144)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 8, 8, 144)   1296        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 8, 8, 144)   576         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 8, 8, 144)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 8, 8, 48)     6912        ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 8, 8, 48)    192         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 8, 8, 288)    13824       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 8, 8, 288)   1152        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 8, 8, 288)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 8, 8, 288)   2592        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 8, 8, 288)   1152        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 8, 8, 288)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 8, 8, 48)     13824       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 8, 8, 48)    192         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 8, 8, 48)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 8, 8, 288)    13824       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 8, 8, 288)   1152        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 8, 8, 288)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 8, 8, 288)   2592        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 8, 8, 288)   1152        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 8, 8, 288)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 8, 8, 48)     13824       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 8, 8, 48)    192         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 8, 8, 48)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 8, 8, 288)    13824       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 8, 8, 288)   1152        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 8, 8, 288)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 8, 8, 288)   2592        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 8, 8, 288)   1152        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 8, 8, 288)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 8, 8, 48)     13824       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 8, 8, 48)    192         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 8, 8, 48)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 8, 8, 288)    13824       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 8, 8, 288)   1152        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 8, 8, 288)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 8, 8, 288)   2592        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 8, 8, 288)   1152        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 8, 8, 288)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 8, 8, 72)     20736       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 8, 8, 72)    288         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 8, 8, 432)    31104       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 8, 8, 432)   1728        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 8, 8, 432)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 8, 8, 432)   3888        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 8, 8, 432)   1728        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 8, 8, 432)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 8, 8, 72)     31104       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 8, 8, 72)    288         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 8, 8, 72)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 8, 8, 432)    31104       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 8, 8, 432)   1728        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 8, 8, 432)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 8, 8, 432)   3888        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 8, 8, 432)   1728        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 8, 8, 432)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 8, 8, 72)     31104       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 8, 8, 72)    288         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 8, 8, 72)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 8, 8, 432)    31104       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 8, 8, 432)   1728        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 8, 8, 432)    0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 9, 9, 432)    0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 4, 4, 432)   3888        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 4, 4, 432)   1728        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 4, 4, 432)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 4, 4, 120)    51840       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 4, 4, 120)   480         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 4, 4, 720)    86400       ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 4, 4, 720)   2880        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 4, 4, 720)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 4, 4, 720)   6480        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 4, 4, 720)   2880        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 4, 4, 720)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 4, 4, 120)    86400       ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 4, 4, 120)   480         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 4, 4, 120)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 4, 4, 720)    86400       ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 4, 4, 720)   2880        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 4, 4, 720)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 4, 4, 720)   6480        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 4, 4, 720)   2880        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 4, 4, 720)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 4, 4, 120)    86400       ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 4, 4, 120)   480         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 4, 4, 120)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 4, 4, 720)    86400       ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 4, 4, 720)   2880        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 4, 4, 720)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 4, 4, 720)   6480        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 4, 4, 720)   2880        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 4, 4, 720)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 4, 4, 240)    172800      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 4, 4, 240)   960         ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 4, 4, 1280)   307200      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 4, 4, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 4, 4, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1280)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1)            1281        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,383,345
# Trainable params: 1,281
# Non-trainable params: 1,382,064
# __________________________________________________________________________________________________

# %% [markdown]
# ## Set Up Callbacks and Training Parameters

# %%
from keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime

patience = 5  # INCREASED from 3 for more stable training

start_lr = 0.0001  # INCREASED from 0.00001
min_lr = 0.00001
max_lr = 0.0003   # INCREASED from 0.00005

batch_size = 32  # REDUCED from 32 to use less memory per batch

rampup_epochs = 10  # INCREASED from 5
sustain_epochs = 5  # INCREASED from 0
exp_decay = .85  # INCREASED from .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if ((logs.get('accuracy')>=0.995)):  # ADJUSTED threshold
            print("\nLimits Reached cancelling training!")
            self.model.stop_training = True

end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=True)  # Set verbose to True to monitor LR changes

early_stopping = EarlyStopping(patience=patience, monitor='val_loss',
                               mode='min', restore_best_weights=True, 
                               verbose=1, min_delta=.001)  # INCREASED min_delta

lr_plat = ReduceLROnPlateau(patience=3, mode='min', verbose=1, factor=0.7)  # ADJUSTED parameters

# Create logs directory if it doesn't exist
if not os.path.exists('./logs'):
    os.makedirs('./logs')

log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, write_graph=True, histogram_freq=1)

# Save model to the model directory
checkpoint_filepath = 'model/ModelWeights.weights.h5'
model_save_path = 'model/model.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                    save_weights_only=True,
                                    monitor='val_loss',
                                    mode='min',
                                    verbose=1,
                                    save_best_only=True)

callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

# %% [markdown]
# ## Train the Model

# %%
print('Training model...')
# Uncomment to load pre-trained weights if available
# model.load_weights('./model/ModelWeights.h5')

history = model.fit(X_train_nn, y_train, 
                    epochs=epochs,
                    callbacks=callbacks,
                    validation_data=(X_test_nn, y_test),
                    batch_size=batch_size)

print('\nRestoring best weights...')
model.load_weights(checkpoint_filepath)
# Out:
# Training model...
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/50
# 500/500 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.6726
# Epoch 1: val_loss improved from inf to 0.30245, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 139s 265ms/step - loss: 0.6841 - accuracy: 0.6726 - val_loss: 0.3024 - val_accuracy: 0.8820 - lr: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.00012.
# Epoch 2/50
# 500/500 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.8634
# Epoch 2: val_loss improved from 0.30245 to 0.18166, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 123s 247ms/step - loss: 0.3230 - accuracy: 0.8634 - val_loss: 0.1817 - val_accuracy: 0.9335 - lr: 1.2000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00014.
# Epoch 3/50
# 500/500 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9137
# Epoch 3: val_loss improved from 0.18166 to 0.13287, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 121s 242ms/step - loss: 0.2163 - accuracy: 0.9137 - val_loss: 0.1329 - val_accuracy: 0.9500 - lr: 1.4000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00015999999999999999.
# Epoch 4/50
# 500/500 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9367
# Epoch 4: val_loss improved from 0.13287 to 0.10429, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 118s 236ms/step - loss: 0.1650 - accuracy: 0.9367 - val_loss: 0.1043 - val_accuracy: 0.9655 - lr: 1.6000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.00017999999999999998.
# Epoch 5/50
# 500/500 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9492
# Epoch 5: val_loss improved from 0.10429 to 0.08699, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 120s 241ms/step - loss: 0.1404 - accuracy: 0.9492 - val_loss: 0.0870 - val_accuracy: 0.9725 - lr: 1.8000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.00019999999999999998.
# Epoch 6/50
# 500/500 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9576
# Epoch 6: val_loss improved from 0.08699 to 0.07546, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 120s 241ms/step - loss: 0.1173 - accuracy: 0.9576 - val_loss: 0.0755 - val_accuracy: 0.9765 - lr: 2.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00021999999999999998.
# Epoch 7/50
# 500/500 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9631
# Epoch 7: val_loss improved from 0.07546 to 0.06790, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 119s 238ms/step - loss: 0.1042 - accuracy: 0.9631 - val_loss: 0.0679 - val_accuracy: 0.9793 - lr: 2.2000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.00023999999999999998.
# Epoch 8/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9673
# Epoch 8: val_loss improved from 0.06790 to 0.05909, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 121s 242ms/step - loss: 0.0947 - accuracy: 0.9673 - val_loss: 0.0591 - val_accuracy: 0.9815 - lr: 2.4000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.00026.
# Epoch 9/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9704
# Epoch 9: val_loss improved from 0.05909 to 0.05593, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 117s 234ms/step - loss: 0.0863 - accuracy: 0.9704 - val_loss: 0.0559 - val_accuracy: 0.9825 - lr: 2.6000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00028.
# Epoch 10/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9722
# Epoch 10: val_loss improved from 0.05593 to 0.05036, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 120s 239ms/step - loss: 0.0791 - accuracy: 0.9722 - val_loss: 0.0504 - val_accuracy: 0.9860 - lr: 2.8000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0003.
# Epoch 11/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9732
# Epoch 11: val_loss improved from 0.05036 to 0.04963, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 122s 245ms/step - loss: 0.0772 - accuracy: 0.9732 - val_loss: 0.0496 - val_accuracy: 0.9840 - lr: 3.0000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0003.
# Epoch 12/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9766
# Epoch 12: val_loss improved from 0.04963 to 0.04513, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 122s 244ms/step - loss: 0.0726 - accuracy: 0.9766 - val_loss: 0.0451 - val_accuracy: 0.9877 - lr: 3.0000e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0003.
# Epoch 13/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9743
# Epoch 13: val_loss improved from 0.04513 to 0.04349, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 117s 235ms/step - loss: 0.0728 - accuracy: 0.9743 - val_loss: 0.0435 - val_accuracy: 0.9858 - lr: 3.0000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0003.
# Epoch 14/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9775
# Epoch 14: val_loss improved from 0.04349 to 0.04118, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 119s 239ms/step - loss: 0.0678 - accuracy: 0.9775 - val_loss: 0.0412 - val_accuracy: 0.9877 - lr: 3.0000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0003.
# Epoch 15/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9768
# Epoch 15: val_loss improved from 0.04118 to 0.03967, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 121s 242ms/step - loss: 0.0690 - accuracy: 0.9768 - val_loss: 0.0397 - val_accuracy: 0.9885 - lr: 3.0000e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0003.
# Epoch 16/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9778
# Epoch 16: val_loss improved from 0.03967 to 0.03798, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 120s 240ms/step - loss: 0.0662 - accuracy: 0.9778 - val_loss: 0.0380 - val_accuracy: 0.9885 - lr: 3.0000e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0002565.
# Epoch 17/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9796
# Epoch 17: val_loss improved from 0.03798 to 0.03777, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 119s 238ms/step - loss: 0.0616 - accuracy: 0.9796 - val_loss: 0.0378 - val_accuracy: 0.9883 - lr: 2.5650e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.00021952499999999993.
# Epoch 18/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9781
# Epoch 18: val_loss improved from 0.03777 to 0.03657, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 118s 236ms/step - loss: 0.0622 - accuracy: 0.9781 - val_loss: 0.0366 - val_accuracy: 0.9887 - lr: 2.1952e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.00018809624999999993.
# Epoch 19/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9789
# Epoch 19: val_loss did not improve from 0.03657
# 500/500 [==============================] - 123s 246ms/step - loss: 0.0624 - accuracy: 0.9789 - val_loss: 0.0369 - val_accuracy: 0.9883 - lr: 1.8810e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.00016138181249999994.
# Epoch 20/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9799
# Epoch 20: val_loss improved from 0.03657 to 0.03628, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 119s 237ms/step - loss: 0.0626 - accuracy: 0.9799 - val_loss: 0.0363 - val_accuracy: 0.9895 - lr: 1.6138e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.00013867454062499996.
# Epoch 21/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9799
# Epoch 21: val_loss improved from 0.03628 to 0.03622, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 127s 254ms/step - loss: 0.0593 - accuracy: 0.9799 - val_loss: 0.0362 - val_accuracy: 0.9890 - lr: 1.3867e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.00011937335953124996.
# Epoch 22/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9781
# Epoch 22: val_loss improved from 0.03622 to 0.03566, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 116s 231ms/step - loss: 0.0633 - accuracy: 0.9781 - val_loss: 0.0357 - val_accuracy: 0.9910 - lr: 1.1937e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.00010296735560156246.
# Epoch 23/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9798
# Epoch 23: val_loss improved from 0.03566 to 0.03553, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 112s 225ms/step - loss: 0.0603 - accuracy: 0.9798 - val_loss: 0.0355 - val_accuracy: 0.9905 - lr: 1.0297e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 8.90222522613281e-05.
# Epoch 24/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9787
# Epoch 24: val_loss improved from 0.03553 to 0.03546, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 118s 236ms/step - loss: 0.0633 - accuracy: 0.9787 - val_loss: 0.0355 - val_accuracy: 0.9908 - lr: 8.9022e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 7.716891442212887e-05.
# Epoch 25/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9804
# Epoch 25: val_loss improved from 0.03546 to 0.03528, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 113s 226ms/step - loss: 0.0602 - accuracy: 0.9804 - val_loss: 0.0353 - val_accuracy: 0.9910 - lr: 7.7169e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 6.709357725880955e-05.
# Epoch 26/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9799
# Epoch 26: val_loss improved from 0.03528 to 0.03521, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 111s 222ms/step - loss: 0.0603 - accuracy: 0.9799 - val_loss: 0.0352 - val_accuracy: 0.9908 - lr: 6.7094e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 5.852954066998811e-05.
# Epoch 27/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9797
# Epoch 27: val_loss improved from 0.03521 to 0.03515, saving model to model\ModelWeights.weights.h5
# 500/500 [==============================] - 118s 236ms/step - loss: 0.0595 - accuracy: 0.9797 - val_loss: 0.0351 - val_accuracy: 0.9908 - lr: 5.8530e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 5.1250109569489894e-05.
# Epoch 28/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9787
# Epoch 28: val_loss improved from 0.03515 to 0.03512, saving model to model\ModelWeights.weights.h5
# Restoring model weights from the end of the best epoch: 23.
# 500/500 [==============================] - 120s 240ms/step - loss: 0.0618 - accuracy: 0.9787 - val_loss: 0.0351 - val_accuracy: 0.9905 - lr: 5.1250e-05
# Epoch 28: early stopping
#
# Restoring best weights...

# %% [markdown]
# ## Evaluate the Model

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure(figsize=(12, 5))
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    
    # Save the plot to images directory
    if not os.path.exists('images'):
        os.makedirs('images')
    plot_path = os.path.join('images', f'{item}.png')
    plt.savefig(plot_path)
    plt.show()


def get_best_epoch(test_loss, history):
    for key, item in enumerate(history.history.items()):
        (name, arr) = item
        if name == 'val_loss':
            for i in range(len(arr)):
                if round(test_loss, 2) == round(arr[i], 2):
                    return i
    return len(history.history['val_loss']) - 1  # Return last epoch if not found
                
def model_summary(model, history):
    print('---'*30)
    test_loss, test_accuracy = model.evaluate(X_test_nn, y_test, verbose=1)

    if history:
        index = get_best_epoch(test_loss, history)
        print('Best Epoch: ', index)

        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print('Accuracy on train:', train_accuracy, '\tLoss on train:', train_loss)
        print('Accuracy on test:', test_accuracy, '\tLoss on test:', test_loss)
        print_graph('loss', index+1, history)
        print_graph('accuracy', index+1, history)
        print('---'*30)                
         


model_summary(model, history)
# Out:
# ------------------------------------------------------------------------------------------
# 125/125 [==============================] - 24s 193ms/step - loss: 0.0351 - accuracy: 0.9905
# Best Epoch:  12
# Accuracy on train: 0.9742500185966492 	Loss on train: 0.07283024489879608
# Accuracy on test: 0.9904999732971191 	Loss on test: 0.03512489050626755
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## Generate Detailed Metrics

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, classification_report, confusion_matrix

# Evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_nn)


preds = predictions > 0.5

# Confusion matrix
corr_pred = metrics.confusion_matrix(y_test, preds)

n_correct = np.int_((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = np.int_((corr_pred[0][1] + (corr_pred[1][0])))
print('> Wrong Predictions:', n_wrongs)

plt.figure(figsize=(8, 6))
sns.heatmap(corr_pred, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')

# Save confusion matrix to images directory
if not os.path.exists('images'):
    os.makedirs('images')
plt.savefig('images/confusion_matrix.png')
plt.show()

# Classification report
print(metrics.classification_report(y_test, preds, 
                           target_names=["NonViolence", "Violence"]))
# Out:
# Evaluating network...
# 125/125 [==============================] - 24s 179ms/step
# > Correct Predictions: 3962
# > Wrong Predictions: 38
#               precision    recall  f1-score   support
#
#  NonViolence       0.99      0.99      0.99      2000
#     Violence       0.99      0.99      0.99      2000
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.99      0.99      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Save the Full Model in h5 and tflite

# %%
import tensorflow as tf

# Save the full model to the model directory
model.save(model_save_path)
print(f"Model saved to {model_save_path}")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the .tflite model
with open('model/violence_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Model saved to model/model.h5
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\USER\AppData\Local\Temp\tmphotuk9ns\assets
# INFO:tensorflow:Assets written to: C:\Users\USER\AppData\Local\Temp\tmphotuk9ns\assets

# %% [markdown]
# ## Test Prediction on a Sample Video

# %%
# Load the model and test on a sample video frame
from keras.models import load_model
import numpy as np
import cv2

# Test model loading
test_model = load_model(model_save_path)
print("Model loaded successfully!")

# Test on a sample video frame if available
try:
    # Try to find a sample violence video
    sample_video_path = "video/Violence/V_79.mp4"
    if not os.path.exists(sample_video_path):
        sample_video_path = None
        for root, dirs, files in os.walk("video"):
            for file in files:
                if file.endswith(".mp4"):
                    sample_video_path = os.path.join(root, file)
                    break
            if sample_video_path:
                break
    
    if sample_video_path:
        print(f"Testing on sample video: {sample_video_path}")
        cap = cv2.VideoCapture(sample_video_path)
        ret, frame = cap.read()
        if ret:
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame_resized = cv2.resize(frame_rgb, (IMG_SIZE, IMG_SIZE))
            frame_normalized = frame_resized.astype("float32") / 255.0
            
            # Make prediction
            prediction = test_model.predict(np.expand_dims(frame_normalized, axis=0))[0][0]
            print(f"Violence probability: {prediction:.4f}")
            print(f"Prediction: {'Violence' if prediction > 0.5 else 'NonViolence'}")
            
            # Display the frame
            plt.figure(figsize=(8, 8))
            plt.imshow(frame_rgb)
            plt.title(f"Prediction: {'Violence' if prediction > 0.5 else 'NonViolence'} ({prediction:.4f})")
            plt.axis('off')
            plt.show()
        else:
            print("Failed to read frame from video.")
        cap.release()
    else:
        print("No sample video found for testing.")
except Exception as e:
    print(f"Error during sample prediction: {e}")
# Out:
# Model loaded successfully!
# Testing on sample video: video/Violence/V_79.mp4
# 1/1 [==============================] - 1s 730ms/step
# Violence probability: 0.9832
# Prediction: Violence
